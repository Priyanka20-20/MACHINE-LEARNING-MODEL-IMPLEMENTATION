# %%
import pandas as pd 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data = {'Hours_Study':[1,2,3,4,5,6,7,8], 'pass':[0,0,0,1,1,1,1,1]}
df = pd.DataFrame(data)
df
# Out:
#    Hours_Study  pass
# 0            1     0
# 1            2     0
# 2            3     0
# 3            4     1
# 4            5     1
# 5            6     1
# 6            7     1
# 7            8     1

# %%
x = df[['Hours_Study']]
y = df['pass']
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
prediction = model.predict(x_test)
print("Prediction:", prediction)
accuracy = accuracy_score(y_test, prediction)
print("Accuracy:", accuracy)
# Out:
# Prediction: [0 1]
# Accuracy: 1.0

# %%
import pandas as pd
hours = pd.DataFrame({'Hours_Study':[5]})
result = model.predict(hours)
if result[0] == 1:
    print("Student will Pass")
else: 
    print("Student will Fail")
# Out:
# Student will Pass

# %%
import pandas as pd
hours = pd.DataFrame({'Hours_Study':[2]})
result = model.predict(hours)
if result[0] == 1:
    print("Student will Pass")
else: 
    print("Student will Fail")
# Out:
# Student will Fail

# %%
print("Machine Learning Model Successfully Implemented")
print("Accuracy:", accuracy)
print("Prediction Result:", result)
# Out:
# Machine Learning Model Successfully Implemented
# Accuracy: 1.0
# Prediction Result: [0]
